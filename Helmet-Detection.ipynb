# %%
# !nvidia-smi
# Out:
# Fri Nov 20 14:19:27 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.38       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   60C    P8    11W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
#  00376
#  00376.doc
#  0376_VARSHA.zip
#  1590309545598_VulliVarsha_InternshalaResume.pdf
#  20200701_112127.jpg
#  AIML
#  B_0376_0196.zip
#  BD_0009_0376_1222_A3T1.py.gdoc
# 'BD_0009_0376_1222_A3T2 (1).py.gdoc'
#  BD_0009_0376_1222_A3T2.py.gdoc
# 'Big Data'
# 'Big Data 2020_Teamwise_List.gdoc'
# 'BUILDING A PODCAST ENGINE.docx'
# 'BUILDING A PODCAST ENGINE.pdf'
# 'Certificates '
#  Chatbot
#  check_conv.py
#  classification.py
#  class_programs
#  Classroom
# 'Colab Notebooks'
#  Copy_of_siamese2.ipynb
#  DAA-SEM-4
# 'Data Analytics'
# 'Ddco 2 part 1.pdf'
# 'ddco 2 part 2.pdf'
#  Diwali
#  final.gdoc
# 'Google Photos'
# 'How to get started with Drive.pdf'
#  IDS
#  IMG_20200425_124340.jpg
# 'instructions (1).gdoc'
#  instructions.gdoc
# 'Intern_resume1 (1).pdf'
#  Intern_resume1.pdf
#  Intern_resume.pdf
# 'Internship_Resume (1).pdf'
# 'Internship_Resume (2).pdf'
# 'Internship_Resume (3).pdf'
# 'Internship_Resume (4).pdf'
#  Internship_Resume.pdf
# ...

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 14429 (delta 1), reused 3 (delta 0), pack-reused 14421
# Receiving objects: 100% (14429/14429), 13.16 MiB | 22.62 MiB/s, done.
# Resolving deltas: 100% (9807/9807), done.

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/darknet

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %%
#making a copy of yolov3-tiny.cfg
# !cp cfg/yolov3-tiny.cfg cfg/yolov3-tiny_training.cfg

# %%
# !sed -i 's/batch=1/batch=64/' cfg/yolov3-tiny_training.cfg
# !sed -i 's/subdivisions=1/subdivisions=16/' cfg/yolov3-tiny_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 4000/' cfg/yolov3-tiny_training.cfg
# !sed -i '135 s@classes=80@classes=2@' cfg/yolov3-tiny_training.cfg
# !sed -i '177 s@classes=80@classes=2@' cfg/yolov3-tiny_training.cfg
#!sed -i '783 s@classes=80@classes=3@' cfg/yolov3-tiny_training.cfg
# !sed -i '127 s@filters=255@filters=21@' cfg/yolov3-tiny_training.cfg
# !sed -i '171 s@filters=255@filters=21@' cfg/yolov3-tiny_training.cfg
#!sed -i '776 s@filters=255@filters=24@' cfg/yolov3-tiny_training.cfg

# %%
#making a copy of yolov3.cfg
# !cp cfg/yolov3.cfg cfg/yolov3_training.cfg

# %%
# !sed -i 's/batch=1/batch=64/' cfg/yolov3_training.cfg
# !sed -i 's/subdivisions=1/subdivisions=16/' cfg/yolov3_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 4000/' cfg/yolov3_training.cfg
# !sed -i '610 s@classes=80@classes=2@' cfg/yolov3_training.cfg
# !sed -i '696 s@classes=80@classes=2@' cfg/yolov3_training.cfg
# !sed -i '783 s@classes=80@classes=2@' cfg/yolov3_training.cfg
# !sed -i '603 s@filters=255@filters=21@' cfg/yolov3_training.cfg
# !sed -i '689 s@filters=255@filters=21@' cfg/yolov3_training.cfg
# !sed -i '776 s@filters=255@filters=21@' cfg/yolov3_training.cfg

# %%
#creating class names inside a data folder of darknet
# !echo -e 'Helmet\nNo Helmet' > data/obj.names

# %%
# !cp data/obj.names /mydrive/MiniProject/classes.txt

# %%
# !echo -e 'classes= 2\ntrain = data/train.txt\nvalid = data/test.txt\nnames = data/obj.names\nbackup = /mydrive/MiniProject/' > data/obj.data

# %%
# !mkdir data/obj

# %%
# !unzip /mydrive/MiniProject/obj.zip -d data/obj
# Out:
# Archive:  /mydrive/MiniProject/obj.zip
#    creating: data/obj/obj/
#   inflating: data/obj/obj/1.jpg
#   inflating: data/obj/obj/1.txt
#   inflating: data/obj/obj/10.jpg
#   inflating: data/obj/obj/10.txt
#  extracting: data/obj/obj/100.jpg
#   inflating: data/obj/obj/100.txt
#   inflating: data/obj/obj/1000.jpg
#   inflating: data/obj/obj/1000.txt
#   inflating: data/obj/obj/1001.jpg
#   inflating: data/obj/obj/1001.txt
#   inflating: data/obj/obj/1002.jpg
#   inflating: data/obj/obj/1002.txt
#   inflating: data/obj/obj/1003.jpg
#  extracting: data/obj/obj/1003.txt
#   inflating: data/obj/obj/1004.jpg
#   inflating: data/obj/obj/1004.txt
#   inflating: data/obj/obj/1005.jpg
#   inflating: data/obj/obj/1005.txt
#   inflating: data/obj/obj/1006.jpg
#   inflating: data/obj/obj/1006.txt
#   inflating: data/obj/obj/1007.jpg
#   inflating: data/obj/obj/1007.txt
#   inflating: data/obj/obj/1008.jpg
#   inflating: data/obj/obj/1008.txt
#   inflating: data/obj/obj/1009.jpg
# ...

# %%
import glob
images_list = glob.glob("data/obj/obj/*.jpg")
with open("data/train.txt", "w") as f:
  f.write("\n".join(images_list))

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2020-11-20 12:10:32--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M   443KB/s    in 6m 27s
#
# 2020-11-20 12:16:59 (411 KB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 106 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.327432, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 957.786255, iou_loss = 0.000000, total_loss = 957.786255
#  total_bbox = 7565, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 82 Avg (IOU: 0.278321, GIOU: 0.208317), Class: 0.410069, Obj: 0.550074, No Obj: 0.465971, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 119.363739, iou_loss = 1.947693, total_loss = 121.311432
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 94 Avg (IOU: 0.202100, GIOU: 0.004667), Class: 0.585449, Obj: 0.220044, No Obj: 0.385324, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 325.667725, iou_loss = 3.455170, total_loss = 329.122894
# ...

# %%
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg /mydrive/MiniProject/yolov3_training_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 2098, rewritten_bbox = 0.000000 %
#
#  3926: 0.316315, 0.297847 avg loss, 0.001000 rate, 10.102781 seconds, 251264 images, 0.252417 hours left
# Loaded: 0.000054 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 82 Avg (IOU: 0.770392, GIOU: 0.766881), Class: 0.992133, Obj: 0.588676, No Obj: 0.001614, .5R: 1.000000, .75R: 0.750000, count: 4, class_loss = 0.746461, iou_loss = 0.257263, total_loss = 1.003724
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 94 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000049, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.038930, iou_loss = 0.000000, total_loss = 0.038930
# ...
